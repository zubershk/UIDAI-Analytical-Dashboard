# %% [markdown]
# ## Section 1: Imports and loading clean data

# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)

enrol_agg = pd.read_csv("../data/enrolment_clean_monthly.csv")
demo_agg = pd.read_csv("../data/demographic_clean_monthly.csv")
bio_agg = pd.read_csv("../data/biometric_clean_monthly.csv")

# %% [markdown]
# ## Section 2: Merge datasets on common keys

# %%
df = enrol_agg.merge(
    demo_agg,
    on=["state", "year_month"],
    how="left"
).merge(
    bio_agg,
    on=["state", "year_month"],
    how="left"
)

df.head()
# Out:
#                        state year_month  enrol_age_5_17  enrol_age_18_plus  demo_age_5_17  demo_age_18_plus  \
# 0  ANDAMAN & NICOBAR ISLANDS    2025-01               1                  0            0.0              46.0
# 1  ANDAMAN & NICOBAR ISLANDS    2025-02               0                  0            0.0              44.0
# 2  ANDAMAN & NICOBAR ISLANDS    2025-03               0                  0            2.0              71.0
# 3  ANDAMAN & NICOBAR ISLANDS    2025-04               0                  0            0.0              74.0
# 4  ANDAMAN & NICOBAR ISLANDS    2025-05               0                  0            1.0              43.0
#
#    bio_age_5_17  bio_age_18_plus
# 0          98.0            933.0
# 1          17.0             51.0
# 2          27.0             50.0
# 3          11.0             36.0
# 4          13.0             45.0

# %% [markdown]
# ## Section 3: Handle missing update values

# %%
update_cols = [
    "demo_age_5_17", "demo_age_18_plus",
    "bio_age_5_17", "bio_age_18_plus"
]

df[update_cols] = df[update_cols].fillna(0)

# %% [markdown]
# ## Section 4: Compute update-to-enrolment ratios

# %% [markdown]
# ### Step 4.1 Safe division helper

# %%
def safe_ratio(numerator, denominator):
    return numerator / denominator if denominator > 0 else 0

# %% [markdown]
# ### Step 4.2 Apply ratios

# %%
df["demo_ratio_5_17"] = df["demo_age_5_17"] / df["enrol_age_5_17"]
df["demo_ratio_18_plus"] = df["demo_age_18_plus"] / df["enrol_age_18_plus"]

df["bio_ratio_5_17"] = df["bio_age_5_17"] / df["enrol_age_5_17"]
df["bio_ratio_18_plus"] = df["bio_age_18_plus"] / df["enrol_age_18_plus"]

ratio_cols = [
    "demo_ratio_5_17", "demo_ratio_18_plus",
    "bio_ratio_5_17", "bio_ratio_18_plus"
]

df[ratio_cols] = df[ratio_cols].replace([float("inf")], 0).fillna(0)

# %% [markdown]
# ## Section 5: Update intensity metric

# %%
df["total_updates"] = (
    df["demo_age_5_17"] + df["demo_age_18_plus"] +
    df["bio_age_5_17"] + df["bio_age_18_plus"]
)

df["total_enrolment"] = (
    df["enrol_age_5_17"] + df["enrol_age_18_plus"]
)

df["update_intensity"] = df["total_updates"] / df["total_enrolment"]
df["update_intensity"] = df["update_intensity"].replace([float("inf")], 0).fillna(0)

# %% [markdown]
# ## Section 6: Update decay indicators

# %% [markdown]
# ### Step 6.1 Sort properly

# %%
df = df.sort_values(["state", "year_month"])

# %% [markdown]
# ### Step 6.2 Rolling average of update intensity

# %%
df["update_intensity_3m_avg"] = (
    df.groupby("state")["update_intensity"]
    .rolling(window=3, min_periods=1)
    .mean()
    .reset_index(level=0, drop=True)
)

# %% [markdown]
# ### Step 6.3 Decay signal

# %%
df["update_decay_signal"] = (
    df["update_intensity"] - df["update_intensity_3m_avg"]
)

# %% [markdown]
# ## Section 7: Consistency score

# %%
df["update_consistency"] = (
    df.groupby("state")["update_intensity"]
    .transform("std")
)

# %% [markdown]
# ## Section 8: Validation and inspection

# %%
df[[
    "state", "year_month",
    "update_intensity",
    "update_decay_signal",
    "update_consistency"
]].head()

df.describe()
# Out:
#        enrol_age_5_17  enrol_age_18_plus  demo_age_5_17  demo_age_18_plus  bio_age_5_17  bio_age_18_plus  \
# count      573.000000         573.000000     573.000000      5.730000e+02  5.730000e+02     5.730000e+02
# mean      3002.413613         293.431065    8487.554974      7.754124e+04  5.973174e+04     6.201534e+04
# std      14771.082722        1561.373329   27438.548347      2.650285e+05  2.575915e+05     2.536891e+05
# min          0.000000           0.000000       0.000000      0.000000e+00  0.000000e+00     0.000000e+00
# 25%          4.000000           0.000000      53.000000      5.250000e+02  2.340000e+02     2.900000e+02
# 50%        150.000000           7.000000    1029.000000      7.849000e+03  6.327000e+03     4.504000e+03
# 75%        977.000000          65.000000    4666.000000      3.603800e+04  2.078100e+04     2.278900e+04
# max     209320.000000       26247.000000  274604.000000      3.013244e+06  3.864019e+06     3.407643e+06
#
#        demo_ratio_5_17  demo_ratio_18_plus  bio_ratio_5_17  bio_ratio_18_plus  total_updates  total_enrolment  \
# count       573.000000          573.000000      573.000000         573.000000   5.730000e+02       573.000000
# mean         10.098408         1054.109684       71.720185         686.660440   2.077759e+05      3295.844677
# std          25.609590         2441.811760      263.535984        1730.155461   7.571592e+05     15686.613828
# min           0.000000            0.000000        0.000000           0.000000   0.000000e+00         0.000000
# 25%           1.773345            0.000000        7.000000           0.000000   1.222000e+03         5.000000
# 50%           4.265060          298.117162       21.927614         170.833333   2.088700e+04       168.000000
# 75%           9.484018         1105.307692       51.908163         596.000000   8.855800e+04      1063.000000
# max         458.130435        30956.500000     3184.500000       18461.173913   9.192975e+06    215690.000000
#
#        update_intensity  update_intensity_3m_avg  update_decay_signal  update_consistency
# count        573.000000               573.000000           573.000000          572.000000
# mean         265.275827               375.397340          -110.121513          499.830784
# std         1404.349487              1630.522647           824.688145         1295.782684
# min            0.000000                 0.000000        -14448.900000            2.648856
# 25%           35.768116                40.447813           -29.326653           25.832835
# 50%           78.730697                96.220966            -1.333333           84.790541
# 75%          189.637799               224.164113             7.110439          354.640381
# max        29223.000000             29223.000000           553.740741         8008.959592

# %% [markdown]
# ## Section 9: Save feature-engineered dataset

# %%
df.to_csv("../data/feature_engineered_monthly.csv", index=False)
